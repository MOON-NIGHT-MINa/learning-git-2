# %% [markdown]
# <a href="https://colab.research.google.com/github/MOON-NIGHT-MINa/learning-git-2/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import os
import json
import re
from datetime import datetime
from collections import Counter
import requests
import pandas as pd
import matplotlib.pyplot as plt
import pycountry
COLLECTION_NAME = "jobs"
RAW_JSON_PATH = "jobs_raw.json"
RAW_CSV_PATH = "jobs_raw.csv"
CLEAN_JSON_PATH = "jobs_cleaned.json"

# %%
pip install pycountry
# Out:
# Collecting pycountry
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 38.7 MB/s eta 0:00:00
# Installing collected packages: pycountry
# Successfully installed pycountry-24.6.1

# %%
url = "https://remoteok.com/api"
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url, headers=headers, timeout=15)
jobs = response.json()[1:]

# %%
with open(RAW_JSON_PATH, "w", encoding="utf-8") as f:
 json.dump(jobs, f, indent=2)
pd.DataFrame(jobs).to_csv(RAW_CSV_PATH, index=False)
print(" Raw data saved")
# Out:
#  Raw data saved

# %%
import pandas as pd
import pycountry

# Assuming 'jobs' is already fetched (from API or loaded from JSON)
df = pd.DataFrame(jobs)

# Clean company names and position titles
df['company'] = df['company'].str.replace(r'[^\w\s]', '', regex=True).str.title()
df['position'] = df['position'].str.strip()

# Calculate average salary
df['salary_avg'] = df[['salary_min', 'salary_max']].mean(axis=1)

# Identify fully remote jobs
df['fully_remote'] = df['location'].str.contains('worldwide', case=False, na=True)

# Extract countries from location
df['countries'] = df['location'].apply(
    lambda loc: [country.name for country in pycountry.countries if country.name.lower() in str(loc).lower()]
)

# Convert 'date' to datetime and make it timezone-naive
df['date_posted'] = pd.to_datetime(df['date'], errors='coerce').dt.tz_localize(None)

# Calculate how many days ago the job was posted
df['days_ago'] = (pd.to_datetime('now').normalize() - df['date_posted']).dt.days

# Clean tags and extract emails and URLs
df['tags'] = df['tags'].apply(lambda tags: [t.strip().title() for t in tags if t.strip()] if isinstance(tags, list) else [])
df['emails'] = df['description'].str.findall(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b')
df['urls'] = df['description'].str.findall(r'https?://[^\s,]+')

# Save cleaned data to a JSON file
df.to_json("jobs_cleaned.json", orient="records", indent=2)
print("✅ Cleaned data saved")

# Show preview
df.head()
# Out:
# ✅ Cleaned data saved
#                                                 slug       id       epoch  \
# 0  remote-werkstudent-im-bereich-sap-amp-cloud-au...  1093160  1747065604
# 1  remote-senior-golang-engineer-wundergraph-1093159  1093159  1747044902
# 2  remote-software-engineering-team-lead-bloxrout...  1093158  1747040402
# 3           remote-salesforce-lead-bounteous-1093155  1093155  1746979219
# 4  remote-mid-market-sales-account-executive-fisc...  1093154  1746979212
#
#                         date             company  \
# 0  2025-05-12T16:00:04+00:00  Public Cloud Group
# 1  2025-05-12T10:15:02+00:00         Wundergraph
# 2  2025-05-12T09:00:02+00:00      Bloxroute Labs
# 3  2025-05-11T16:00:19+00:00           Bounteous
# 4  2025-05-11T16:00:12+00:00          Fiscalnote
#
#                                         company_logo  \
# 0  https://remoteok.com/assets/img/jobs/f074bbf6c...
# 1
# 2  https://remoteok.com/assets/img/jobs/757eef7e6...
# 3  https://remoteok.com/assets/img/jobs/47bd49ba6...
# 4  https://remoteok.com/assets/img/jobs/8128ee3d9...
#
#                                             position  \
# 0  Werkstudent im Bereich SAP &amp; Cloud Automation
# 1                             Senior Golang Engineer
# 2                     Software Engineering Team Lead
# 3                                    Salesforce Lead
# 4                 Mid Market Sales Account Executive
#
#                                                 tags  \
# 0                             [Python, Cloud, Linux]
# 1        [Golang, Graphql, Senior, Golang, Engineer]
# 2  [Software, Support, Testing, Growth, Code, Lea...
# 3  [Salesforce, Design, Security, Consultancy, Te...
# 4  [Salesforce, Training, Support, Software, Lead...
#
#                                                 logo  \
# 0  https://remoteok.com/assets/img/jobs/f074bbf6c...
# 1
# 2  https://remoteok.com/assets/img/jobs/757eef7e6...
# 3  https://remoteok.com/assets/img/jobs/47bd49ba6...
# 4  https://remoteok.com/assets/img/jobs/8128ee3d9...
#
#                                          description  ...  \
# 0  <p>Als Public Cloud Group sind wir darauf spez...  ...
# 1  Remote - WunderGraph is a fast-growing startup...  ...
# 2  \n<p></p><p><br></p><b>Responsibilities</b><ul...  ...
# 3  <p>Bounteous x Accolite is a premier end-to-en...  ...
# 4  <p><b style="font-size: 18px;">About the Posit...  ...
#
#                                                  url  original  verified  \
# 0  https://remoteOK.com/remote-jobs/remote-werkst...       NaN       NaN
# 1  https://remoteOK.com/remote-jobs/remote-senior...       NaN       NaN
# 2  https://remoteOK.com/remote-jobs/remote-softwa...       NaN       NaN
# 3  https://remoteOK.com/remote-jobs/remote-salesf...       NaN       NaN
# 4  https://remoteOK.com/remote-jobs/remote-mid-ma...       NaN       NaN
#
#   salary_avg fully_remote        countries         date_posted  days_ago  \
# 0    67500.0        False               [] 2025-05-12 16:00:04         0
# 1    95000.0        False               [] 2025-05-12 10:15:02         0
# 2    88750.0        False               [] 2025-05-12 09:00:02         0
# 3    95000.0        False          [India] 2025-05-11 16:00:19         1
# 4    76250.0        False  [United States] 2025-05-11 16:00:12         1
#
#                                               emails  \
# 0  [stephanie.wiedmann@pcg.io, stephanie.wiedmann...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [recruiting.team@fiscalnote.com, recruiting.te...
#
#                                                 urls
# 0  [https://pcg.io/de/karriere-de-at/">Karrierese...
# 1                                                 []
# 2                                                 []
# 3  [https://nam12.safelinks.protection.outlook.co...
# 4  [https://careers.fiscalnote.com/benefits/">htt...
#
# [5 rows x 24 columns]

# %%
import time
import requests
from bs4 import BeautifulSoup

# Custom User-Agent header
headers = {"User-Agent": "Mozilla/5.0"}

# Scrape extra description from job URL
def scrape_job_details(job_url):
    try:
        if not job_url.startswith("http"):
            job_url = f"https://remoteok.com{job_url}"
        res = requests.get(job_url, headers=headers, timeout=10)
        soup = BeautifulSoup(res.text, "html.parser")

        # Try to extract first paragraph from job description
        desc_p = soup.select_one("div.description p")
        return desc_p.text.strip() if desc_p else "No additional details"
    except Exception as e:
        return f"Error: {str(e)}"

# Apply scraper to top 10 jobs
print("🔍 Scraping additional details from job pages...")
for job in jobs[:10]:  # You can change 10 to len(jobs) for full scrape
    url = job.get("url", "")
    if url:
        job["scraped_summary"] = scrape_job_details(url)
        time.sleep(1)  # Optional: sleep to avoid hammering the server
    else:
        job["scraped_summary"] = "No URL provided"
# Out:
# 🔍 Scraping additional details from job pages...

# %%
# Step 4: Create DataFrame
df = pd.DataFrame(jobs)

# Step 5: Clean data
df['company'] = df['company'].str.replace(r'[^\w\s]', '', regex=True).str.title()
df['position'] = df['position'].str.strip()
df['salary_avg'] = df[['salary_min', 'salary_max']].mean(axis=1)

df['fully_remote'] = df['location'].str.contains('worldwide', case=False, na=True)

df['countries'] = df['location'].apply(
    lambda loc: [country.name for country in pycountry.countries if country.name.lower() in str(loc).lower()]
)

df['date_posted'] = pd.to_datetime(df['date'], errors='coerce').dt.tz_localize(None)
df['days_ago'] = (pd.to_datetime('now').normalize() - df['date_posted']).dt.days

df['tags'] = df['tags'].apply(lambda tags: [t.strip().title() for t in tags if t.strip()] if isinstance(tags, list) else [])
df['emails'] = df['description'].str.findall(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b')
df['urls'] = df['description'].str.findall(r'https?://[^\s,]+')
print(df.head())
# Step 6: Save cleaned data
df.to_json(CLEAN_JSON_PATH, orient="records", indent=2)
print("✅ Cleaned job data saved")
# Out:
#                                                 slug       id       epoch  \
# 0  remote-werkstudent-im-bereich-sap-amp-cloud-au...  1093160  1747065604
# 1  remote-senior-golang-engineer-wundergraph-1093159  1093159  1747044902
# 2  remote-software-engineering-team-lead-bloxrout...  1093158  1747040402
# 3           remote-salesforce-lead-bounteous-1093155  1093155  1746979219
# 4  remote-mid-market-sales-account-executive-fisc...  1093154  1746979212
#
#                         date             company  \
# 0  2025-05-12T16:00:04+00:00  Public Cloud Group
# 1  2025-05-12T10:15:02+00:00         Wundergraph
# 2  2025-05-12T09:00:02+00:00      Bloxroute Labs
# 3  2025-05-11T16:00:19+00:00           Bounteous
# 4  2025-05-11T16:00:12+00:00          Fiscalnote
#
#                                         company_logo  \
# 0  https://remoteok.com/assets/img/jobs/f074bbf6c...
# 1
# 2  https://remoteok.com/assets/img/jobs/757eef7e6...
# 3  https://remoteok.com/assets/img/jobs/47bd49ba6...
# 4  https://remoteok.com/assets/img/jobs/8128ee3d9...
#
#                                             position  \
# 0  Werkstudent im Bereich SAP &amp; Cloud Automation
# 1                             Senior Golang Engineer
# 2                     Software Engineering Team Lead
# 3                                    Salesforce Lead
# 4                 Mid Market Sales Account Executive
#
#                                                 tags  \
# 0                             [Python, Cloud, Linux]
# 1        [Golang, Graphql, Senior, Golang, Engineer]
# 2  [Software, Support, Testing, Growth, Code, Lea...
# 3  [Salesforce, Design, Security, Consultancy, Te...
# 4  [Salesforce, Training, Support, Software, Lead...
#
#                                                 logo  \
# 0  https://remoteok.com/assets/img/jobs/f074bbf6c...
# 1
# 2  https://remoteok.com/assets/img/jobs/757eef7e6...
# 3  https://remoteok.com/assets/img/jobs/47bd49ba6...
# 4  https://remoteok.com/assets/img/jobs/8128ee3d9...
#
#                                          description  ...  \
# 0  <p>Als Public Cloud Group sind wir darauf spez...  ...
# 1  Remote - WunderGraph is a fast-growing startup...  ...
# 2  \n<p></p><p><br></p><b>Responsibilities</b><ul...  ...
# 3  <p>Bounteous x Accolite is a premier end-to-en...  ...
# 4  <p><b style="font-size: 18px;">About the Posit...  ...
#
#          scraped_summary  original  verified salary_avg fully_remote  \
# 0            👀 157 views       NaN       NaN    67500.0        False
# 1  No additional details       NaN       NaN    95000.0        False
# 2            👀 280 views       NaN       NaN    88750.0        False
# 3            👀 509 views       NaN       NaN    95000.0        False
# 4            👀 506 views       NaN       NaN    76250.0        False
#
#          countries         date_posted days_ago  \
# 0               [] 2025-05-12 16:00:04        0
# 1               [] 2025-05-12 10:15:02        0
# 2               [] 2025-05-12 09:00:02        0
# 3          [India] 2025-05-11 16:00:19        1
# 4  [United States] 2025-05-11 16:00:12        1
#
#                                               emails  \
# 0  [stephanie.wiedmann@pcg.io, stephanie.wiedmann...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [recruiting.team@fiscalnote.com, recruiting.te...
#
#                                                 urls
# 0  [https://pcg.io/de/karriere-de-at/">Karrierese...
# 1                                                 []
# 2                                                 []
# 3  [https://nam12.safelinks.protection.outlook.co...
# 4  [https://careers.fiscalnote.com/benefits/">htt...
#
# [5 rows x 25 columns]
# ✅ Cleaned job data saved

# %%
# Step 8: Quick summary
print(f"Total jobs: {len(df)}")
print(f"% Fully remote: {df['fully_remote'].mean() * 100:.1f}%")
print(f"Average salary: ${df['salary_avg'].mean():,.0f}")
print(f"Jobs with salary info: {df['salary_avg'].notnull().sum()}")
print(f"Jobs with remote info: {df['fully_remote'].notnull().sum()}")
print(f"Max salary: ${df['salary_avg'].max():,.0f}")
print(f"Min salary: ${df['salary_avg'].min():,.0f}")
print(f"Total remote jobs: {df[df['fully_remote'] == 1].shape[0]}")
print(f"Total in-office jobs: {df[df['fully_remote'] == 0].shape[0]}")
# Out:
# Total jobs: 95
# % Fully remote: 0.0%
# Average salary: $76,132
# Jobs with salary info: 95
# Jobs with remote info: 95
# Max salary: $150,000
# Min salary: $0
# Total remote jobs: 0
# Total in-office jobs: 95

# %%
from collections import Counter
import pandas as pd

# Basic stats
total_jobs = len(df)
pct_fully_remote = df['fully_remote'].mean() * 100
overall_avg_salary = df['salary_avg'].mean()

# Top categories by tag frequency
top_categories = df.explode('tags')['tags'].value_counts().head(10)

# Average salary by category
cat_salary = (
    df.explode('tags')
    .groupby('tags')['salary_avg']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

# Top skills (assuming 'tags' field represents skills too)
top_skills = df.explode('tags')['tags'].value_counts().head(10)

# Top countries (assuming 'countries' is a list)
country_counts = Counter(sum(df['countries'], []))
top_countries = pd.Series(country_counts).sort_values(ascending=False).head(10)

# Top hiring companies
top_companies = df['company'].value_counts().head(10)

# Print summary
print(f"Total jobs: {total_jobs}")
print(f"% Fully remote: {pct_fully_remote:.1f}%")
print(f"Average salary: ${overall_avg_salary:,.0f}")
print("\nTop Categories:")
print(top_categories)
print("\nTop Skills:")
print(top_skills)
print("\nTop Countries:")
print(top_countries)
print("\nTop Hiring Companies:")
print(top_companies)
print("\nTop Salary by Category:")
print(cat_salary)
# Out:
# Total jobs: 95
# % Fully remote: 0.0%
# Average salary: $76,132
#
# Top Categories:
# tags
# Software         39
# Support          38
# Engineer         33
# Digital Nomad    31
# Design           31
# Technical        30
# Management       27
# Growth           25
# Lead             22
# Code             22
# Name: count, dtype: int64
#
# Top Skills:
# tags
# Software         39
# Support          38
# Engineer         33
# Digital Nomad    31
# Design           31
# Technical        30
# Management       27
# Growth           25
# Lead             22
# Code             22
# Name: count, dtype: int64
#
# Top Countries:
# United States    9
# Canada           3
# India            2
# Australia        2
# Malaysia         1
# Colombia         1
# dtype: int64
#
# Top Hiring Companies:
# company
# Contra                               8
# Smallstep                            3
# Gauntlet                             3
# Anchorage Digital                    3
# Nextech                              2
# Tether Operations Limited            2
# Manta Network Powered By P0X Labs    2
# Moonpay                              2
# Lead Bank                            2
# Firework                             2
# Name: count, dtype: int64
#
# Top Salary by Category:
# tags
# Data                       150000.0
# Artificial Intelligence    130000.0
# Ai                         130000.0
# Deep Learning              130000.0
# Macos                      130000.0
# Machine Learning           130000.0
# English                    130000.0
# Neural Networks            130000.0
# Next                       130000.0
# Postgres                   130000.0
# Name: salary_avg, dtype: float64

# %%
import matplotlib.pyplot as plt

# Bar chart: Top Skills
top_skills.plot(kind='bar', title='Top Skills', figsize=(8, 4))
plt.tight_layout()
plt.show()

# Horizontal bar chart: Highest-Paying Categories
cat_salary.plot(kind='barh', title='Highest-Paying Categories', figsize=(8, 4))
plt.tight_layout()
plt.show()

# Bar chart: Top Countries
top_countries.plot(kind='bar', title='Top Countries', figsize=(8, 4))
plt.tight_layout()
plt.show()

# Bar chart: Top Hiring Companies
top_companies.plot(kind='bar', title='Top Hiring Companies', figsize=(8, 4))
plt.tight_layout()
plt.show()

# Pie chart: Skill Distribution
top_skills.plot(
    kind='pie',
    title='Skill Distribution',
    autopct='%1.1f%%',
    figsize=(6, 6),
    ylabel=''  # Removes default y-label
)
plt.tight_layout()
plt.show()

# Line chart: Salary Trend by Category
cat_salary.sort_values().plot(
    kind='line',
    title='Salary Trend by Category',
    marker='o',
    figsize=(8, 4)
)
plt.tight_layout()
plt.show()

# %%
from pymongo import MongoClient
# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['remote_jobs_db']
collection = db['cleaned_jobs'] # New collection for the cleaned jobs
# Drop the collection if you want a fresh start
# Convert DataFrame to list of dictionaries
job_data = df.to_dict(orient='records')
# Insert cleaned jobs into MongoDB

# Close connection
client.close()
print(" Cleaned job data saved to MongoDB (collection: cleaned_jobs)")
# Out:
#  Cleaned job data saved to MongoDB (collection: cleaned_jobs)

# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.5 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 19.4 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.12.1
